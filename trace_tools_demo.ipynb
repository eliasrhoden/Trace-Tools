# %% [markdown]
# # Trace Tools demo
#
# Here I will show how to parse a Frequency measurement file.

# %%
import TraceTools as tt 
import matplotlib.pyplot as plt 

freq = tt.parse_freq_meas_file(r'demo\freq_trace.XML')

freq
# Out:
# FrequencyMeasurement(machine='', timestamp='', input_time_series=[TimeSeries(t=array([0.00000e+00, 1.25000e-04, 2.50000e-04, ..., 2.55500e-01,
#        2.55625e-01, 2.55750e-01]), values=array([0.62831641, 0.20944161, 0.62831641, ..., 0.20944161, 0.20944161,
#        0.20944161])), TimeSeries(t=array([0.00000e+00, 1.25000e-04, 2.50000e-04, ..., 2.55500e-01,
#        2.55625e-01, 2.55750e-01]), values=array([-0.62831641, -0.20944161, -0.62831641, ..., -0.20944161,
#        -0.20944161, -0.20944161]))], output_time_series=[TimeSeries(t=array([0.00000e+00, 1.25000e-04, 2.50000e-04, ..., 2.55500e-01,
#        2.55625e-01, 2.55750e-01]), values=array([0.32488274, 0.28256344, 0.27170274, ..., 0.31243038, 0.29314327,
#        0.28921094])), TimeSeries(t=array([0.00000e+00, 1.25000e-04, 2.50000e-04, ..., 2.55500e-01,
#        2.55625e-01, 2.55750e-01]), values=array([-0.31168136, -0.28509137, -0.27320077, ..., -0.32844056,
# ...

# %%
tt.plot_freq(freq.plant_freq_response)

# %%
for i in range(2):
    ts = freq.output_time_series[i]
    plt.plot(ts.t, ts.values)
